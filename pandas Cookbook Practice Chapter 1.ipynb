# %% [markdown]
# #Chapter 1

# %%
import pandas as pd
# %pylab inline
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
figsize(15, 5)

# %% [markdown]
# ## Reading data from csv

# %%
# this is to fix the bug about unicode errors... shouldn't be a problem in python 3
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
# read the csv
# specify delimiter, fix encoding, parse the date(day first format), use the column of date as row index
fixed_df = pd.read_csv('data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]

# %% [markdown]
# ## Selecting column

# %%
fixed_df['Berri 1']
# Out:
# Date
# 2012-01-01     35
# 2012-01-02     83
# 2012-01-03    135
# 2012-01-04    144
# 2012-01-05    197
# 2012-01-06    146
# 2012-01-07     98
# 2012-01-08     95
# 2012-01-09    244
# 2012-01-10    397
# 2012-01-11    273
# 2012-01-12    157
# 2012-01-13     75
# 2012-01-14     32
# 2012-01-15     54
# ...
# 2012-10-22    3650
# 2012-10-23    4177
# 2012-10-24    3744
# 2012-10-25    3735
# 2012-10-26    4290
# 2012-10-27    1857
# 2012-10-28    1310
# 2012-10-29    2919
# 2012-10-30    2887
# 2012-10-31    2634
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310

# %% [markdown]
# ## Plotting column

# %% [markdown]
# As simple as adding `.plot()`.

# %%
fixed_df['Berri 1'].plot()

# %% [markdown]
# Plot multiple columns and change the size of plot.

# %%
fixed_df.plot(figsize=(15, 10))

# %% [markdown]
# ##Combine them all...

# %% [markdown]
# To read, select, and plot data, the following code works:

# %%
df = pd.read_csv('data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df['Berri 1'].plot()

# %% [markdown]
# ##Summary
# + `pd.read_csv()`
# + `df['index']`
# + `df.plot()`
